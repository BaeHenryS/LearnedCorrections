# %%
from phi.tf.flow import *
import numpy as np

# %%
N = 128
DX = 2./N
STEPS = 400
DT = 1./STEPS
NU = 0.01/(N*np.pi)

# initialization of velocities, cell centers of a CenteredGrid have DX/2 offsets for linspace()
INITIAL_NUMPY = np.asarray( [-np.sin(np.pi * x) for x in np.linspace(-1+DX/2,1-DX/2,N)] ) # 1D numpy array

INITIAL = math.tensor(INITIAL_NUMPY, spatial('x') ) # convert to phiflow tensor

# %%
velocity = CenteredGrid(INITIAL, extrapolation.PERIODIC, x=N, bounds=Box(x=(-1,1)))
vt = advect.semi_lagrangian(velocity, velocity, DT)
#velocity = CenteredGrid(lambda x: -math.sin(np.pi * x), extrapolation.PERIODIC, x=N, bounds=Box(x=(-1,1)))
#velocity = CenteredGrid(Noise(), extrapolation.PERIODIC, x=N, bounds=Box(x=(-1,1))) # random init

print("Velocity tensor shape: "   + format( velocity.shape )) # == velocity.values.shape
print("Velocity tensor type: "    + format( type(velocity.values) ))
print("Velocity tensor entries 10 to 14: " + format( velocity.values.numpy('x')[10:15] ))
# Out:
# Velocity tensor shape: (xˢ=128)
# Velocity tensor type: <class 'phiml.math._tensors.NativeTensor'>
# Velocity tensor entries 10 to 14: [0.4928982  0.53499764 0.57580817 0.6152316  0.65317285]

# %%
velocities = [velocity]
age = 0.
for i in range(STEPS):
    v1 = diffuse.explicit(velocities[-1], NU, DT)
    v2 = advect.semi_lagrangian(v1, v1, DT)
    age += DT
    #velocities.append(v2)
    if i%20 == 0:
        print(i)

print("New velocity content at t={}: {}".format( age, velocities[-1].values.numpy('x,vector')[0:5] ))
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/0h/2pkv9xxd45lfrx3mx45bxhxw0000gn/T/ipykernel_90949/2154479498.py in ?()
#       3 velocities = [velocity]
#       4 age = 0.
# ----> 5 for i in range(STEPS):
#       6     v1 = diffuse.explicit(velocities[-1], NU, DT)
#       7     v2 = advect.semi_lagrangian(v1, v1, DT)
#       8     age += DT
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phi/physics/advect.py in ?(field, velocity, dt, integrator)
#     155         Field with same sample points as `field`
#     156
#     157     """
#     158     lookup = integrator(field.elements, velocity, -dt)
# --> 159     interpolated = reduce_sample(field, lookup)
#     160     return field.with_values(interpolated)
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phi/field/_field.py in ?(field, geometry, dim, **kwargs)
#     407             sampled = [field._sample(p, **kwargs) for p in geometry.unstack(channel(geometry).without('vector').name)]
#     408         dim = dim.with_size(geometry.shape.channel.item_names[0])
#     409         return math.stack(sampled, dim)
#     410     else:  # Nothing to reduce
# --> 411         return field._sample(geometry, **kwargs)
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phi/field/_grid.py in ?(self, geometry, **kwargs)
#     243                 if fast_resampled is not NotImplemented:
#     244                     return fast_resampled
#     245         points = geometry.center
#     246         local_points = self.box.global_to_local(points) * self.resolution - 0.5
# --> 247         resampled_values = math.grid_sample(self.values, local_points, self.extrapolation, bounds=self.bounds)
#     248         if isinstance(self._extrapolation, FieldEmbedding):
#     249             if isinstance(geometry, GridCell) and ((geometry.bounds.upper <= self.bounds.upper).all or (geometry.bounds.lower >= self.bounds.lower).all):
#     250                 # geometry is a subgrid of self
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/math/_ops.py in ?(grid, coordinates, extrap, **kwargs)
#    1042
#    1043     Returns:
#    1044         `Tensor` with channel dimensions of `grid`, spatial and instance dimensions of `coordinates` and combined batch dimensions.
#    1045     """
# -> 1046     result = broadcast_op(functools.partial(_grid_sample, extrap=extrap, pad_kwargs=kwargs), [grid, coordinates])
#    1047     return result
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/math/_ops.py in ?(operation, tensors, iter_dims, no_return)
#    1097             iter_dims.update(tensor.shape.shape.without('dims').names)
#    1098             if isinstance(tensor, TensorStack) and tensor.requires_broadcast:
#    1099                 iter_dims.add(tensor._stack_dim.name)
#    1100     if len(iter_dims) == 0:
# -> 1101         return operation(*tensors)
#    1102     else:
#    1103         if isinstance(iter_dims, Shape):
#    1104             iter_dims = iter_dims.names
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/math/_ops.py in ?(grid, coordinates, extrap, pad_kwargs)
#    1081     # fallback to slower grid sampling
#    1082     neighbors = _closest_grid_values(grid, coordinates, extrap or e_.ZERO, '_closest_', pad_kwargs)
#    1083     binary = meshgrid(channel, **{f'_closest_{dim}': (0, 1) for dim in grid.shape.spatial.names}, stack_dim=channel(coordinates))
#    1084     right_weights = coordinates % 1
# -> 1085     weights = prod(binary * right_weights + (1 - binary) * (1 - right_weights), 'vector')
#    1086     result = sum_(neighbors * weights, dim=[f"_closest_{dim}" for dim in grid.shape.spatial.names])
#    1087     return result
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/math/_tensors.py in ?(self, other)
#     616     def __mul__(self, other):
# --> 617         return self._op2(other, lambda x, y: x * y, lambda x, y: choose_backend(x, y).mul(x, y), 'mul', '*')
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/math/_tensors.py in ?(self, other, operator, native_function, op_name, op_symbol, switch_args)
#    1299         broadcast_shape = self._native_shape & other_tensor._native_shape
#    1300         natives = [t.native(order=broadcast_shape, singleton_for_const=True) if t.rank > 0 else t.native() for t in [self, other_tensor]]
#    1301         if switch_args:
#    1302             natives = natives[::-1]
# -> 1303         result_tensor = native_function(*natives)
#    1304         return NativeTensor(result_tensor, broadcast_shape, self._shape & other_tensor._shape)
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/math/_tensors.py in ?(x, y)
# --> 617         return self._op2(other, lambda x, y: x * y, lambda x, y: choose_backend(x, y).mul(x, y), 'mul', '*')
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/backend/tensorflow/_tf_backend.py in ?(self, a, b)
#     751     def mul(self, a, b):
#     752         with self._device_for(a, b):
#     753             a, b = self.auto_cast(a, b)
# --> 754             return a * b
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/backend/_backend.py in ?(self, bool_to_int, int_to_float, *tensors)
#     188             result_type = DType(int, 32)
#     189         if result_type.kind == int and int_to_float:
#     190             result_type = DType(float, self.precision)
#     191         if result_type.kind in (int, float, complex, bool):  # do not cast everything to string!
# --> 192             tensors = [self.cast(t, result_type) for t in tensors]
#     193         return tensors
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/backend/_backend.py in ?(.0)
# --> 192     def auto_cast(self, *tensors, bool_to_int=False, int_to_float=False) -> list:
#     193         """
#     194         Determins the appropriate values type resulting from operations involving the tensors as input.
#     195
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/phiml/backend/tensorflow/_tf_backend.py in ?(self, x, dtype)
#     617         if self.dtype(x) == dtype:
#     618             return x
#     619         else:
#     620             with tf.device(x.device):
# --> 621                 return tf.cast(x, to_numpy_dtype(dtype))
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#    1265         if result is not OpDispatcher.NOT_SUPPORTED:
#    1266           return result
#    1267         else:
# -> 1268           raise
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py in ?(x, dtype, name)
#    1021             "intended."
#    1022         )
#    1023       if x.dtype != base_type:
#    1024         x = gen_math_ops.cast(x, base_type, name=name)
# -> 1025     return x
#
# ~/miniconda3/envs/90R/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, DstT, Truncate, name)
#    2058       return _result
#    2059     except _core._NotOkStatusException as e:
#    2060       _ops.raise_from_not_ok_status(e, name)
#    2061     except _core._FallbackException:
# -> 2062       pass
#    2063     try:
#    2064       return cast_eager_fallback(
#    2065           x, DstT=DstT, Truncate=Truncate, name=name, ctx=_ctx)
#
# KeyboardInterrupt:

# %%
# get "velocity.values" from each phiflow state with a channel dimensions, i.e. "vector"
vels = [v.values.numpy('x,vector') for v in velocities] # gives a list of 2D arrays 

import pylab

fig = pylab.figure().gca()
fig.plot(np.linspace(-1,1,len(vels[ 0].flatten())), vels[ 0].flatten(), lw=2, color='blue',  label="t=0")
fig.plot(np.linspace(-1,1,len(vels[10].flatten())), vels[10].flatten(), lw=2, color='green', label="t=0.3125")
fig.plot(np.linspace(-1,1,len(vels[20].flatten())), vels[20].flatten(), lw=2, color='cyan',  label="t=0.625")
fig.plot(np.linspace(-1,1,len(vels[32].flatten())), vels[32].flatten(), lw=2, color='purple',label="t=1")
pylab.xlabel('x'); pylab.ylabel('u'); pylab.legend()

# %%
import numpy as np
import os
from scipy.signal import convolve
import burgers_1d_batch
from phi.tf.flow import *

import tensorflow as tf
from tensorflow.keras import layers, models
import concurrent.futures

import math
import random
import pickle

import json

class DataLoader:
    def __init__(self, simulation_path, k):
        self.simulation_path = simulation_path
        self.k = k
        self.num_simulations, self.num_timesteps = self._count_simulations_and_timesteps()
        self.data = self._load_velocity_data()
        self.batched_data = None
        self.batched_std = None
        

    def _count_simulations_and_timesteps(self):
        # Count the number of simulation directories
        simulation_dirs = [d for d in os.listdir(self.simulation_path) if os.path.isdir(os.path.join(self.simulation_path, d))]
        num_simulations = len(simulation_dirs)

        # Count the number of velocity files in the first simulation directory
        first_sim_dir = os.path.join(self.simulation_path, simulation_dirs[0])
        velocity_files = [f for f in os.listdir(first_sim_dir) if f.startswith('velocity') and f.endswith('.npz')]
        num_timesteps = len(velocity_files)
        print(f"Number of simulations: {num_simulations}, Number of timesteps: {num_timesteps}")
        return num_simulations, num_timesteps
    

    def _load_velocity_data(self):
            def load_data_with_progress(sim):
                result = self._load_simulation_data(sim)
                progress = (sim + 1) / self.num_simulations * 100  # Calculate progress
                print(f"Progress: {progress:.2f}%")
                return result

            with concurrent.futures.ThreadPoolExecutor() as executor:
                data = list(executor.map(load_data_with_progress, range(self.num_simulations)))
            # Filter out empty arrays from each array in data before flattening
            return [element for array in data if array for element in array]                

    def _load_simulation_data(self, sim):
        sim_dir = os.path.join(self.simulation_path, f'sim_{sim:06d}')
        # Load params.json in the simulation directory
        params_file = os.path.join(sim_dir, 'params.json')
        if not os.path.exists(params_file):
            print(f"Params file {params_file} not found, skipping to the next simulation.")
            return []
        
        params_file = json.load(open(params_file))

        A_values = np.array(params_file["A_values"])
        ω_values = np.array(params_file["ω_values"])
        φ_values = np.array(params_file["φ_values"])
        l_values = np.array(params_file["l_values"])
        combined_array = np.column_stack((A_values, ω_values, φ_values, l_values))


        if not os.path.exists(sim_dir):
            print(f"Simulation directory {sim_dir} not found, skipping to the next simulation.")
            return []  # Return empty list for missing simulations
        sim_data = []
        for t in range(self.num_timesteps - self.k-1):
            try:
                velocity_data = np.stack([np.load(os.path.join(sim_dir, f'velocity_{(t + i):06d}.npz'))['data'] for i in range(0, self.k + 1)], axis=0)
                advection_diffusion_data = np.stack([np.load(os.path.join(sim_dir, f'advection_diffusion_{(t + i):06d}.npz'))['data'] for i in range(0, self.k+1)], axis=0)


                sim_data.append((sim, velocity_data, advection_diffusion_data, t, combined_array))

            except FileNotFoundError:
                print(f"File not found for simulation {sim}, timestep {t}, skipping to the next timestep.")


        print(f"Loaded simulation {sim + 1}/{self.num_simulations}")
        return sim_data
    
    def _compute_batch_std(self, batch_data):

        velocity_data_list = []
        advection_diffusion_data_list = []

        for sim, velocity_data, advection_diffusion_data, _ , _ in batch_data:
            velocity_data_list.append(velocity_data)
            advection_diffusion_data_list.append(advection_diffusion_data)

        # Convert lists to numpy arrays
        velocity_data_array = np.array(velocity_data_list)
        advection_diffusion_data_array = np.array(advection_diffusion_data_list)


        velocity_std = np.std(velocity_data_array.flatten())
        advection_diffusion_std = np.std(advection_diffusion_data_array.flatten())

        return velocity_std, advection_diffusion_std
    def prepare_batches(self, batch_size):
        self.batched_data = []
        self.batched_std = []

        random.shuffle(self.data)  # Shuffle the data before creating batches
        total_batches = int(math.ceil(len(self.data) / batch_size))
        
        for batch_idx in range(total_batches):
            start_idx = batch_idx * batch_size
            end_idx = start_idx + batch_size
            batch_data = self.data[start_idx:end_idx]

            
            self.batched_data.append(batch_data)
            self.batched_std.append(self._compute_batch_std(batch_data))

        return self.batched_data
    
    def save_data_as_pickle(self, data, filename):
        with open(filename, 'wb') as file:
            pickle.dump(data, file)

    def load_from_pickle(self, filename):
        with open(filename, 'rb') as file:
            self.data = pickle.load(file)
        return self.data
# Out:
# 2024-07-19 16:19:40.575245: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-19 16:19:40.618629: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-19 16:19:40.637587: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-19 16:19:40.637624: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-19 16:19:40.650650: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-19 16:19:46.377748: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-19 16:19:57.379041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:0 with 18211 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 3g.20gb, pci bus id: 0000:ca:00.0, compute capability: 8.0
# 2024-07-19 16:19:57.392963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18211 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 3g.20gb, pci bus id: 0000:ca:00.0, compute capability: 8.0

# %%
dataloader = DataLoader('./output', 1)
# Out:
# Number of simulations: 124, Number of timesteps: 2000
# File not found for simulation 5, timestep 125, skipping to the next timestep.
# File not found for simulation 5, timestep 126, skipping to the next timestep.
# File not found for simulation 5, timestep 127, skipping to the next timestep.
# File not found for simulation 5, timestep 128, skipping to the next timestep.
# File not found for simulation 5, timestep 129, skipping to the next timestep.
# File not found for simulation 5, timestep 130, skipping to the next timestep.
# File not found for simulation 5, timestep 131, skipping to the next timestep.
# File not found for simulation 5, timestep 132, skipping to the next timestep.
# File not found for simulation 5, timestep 133, skipping to the next timestep.
# File not found for simulation 5, timestep 134, skipping to the next timestep.
# File not found for simulation 5, timestep 135, skipping to the next timestep.
# File not found for simulation 5, timestep 136, skipping to the next timestep.
# File not found for simulation 5, timestep 137, skipping to the next timestep.
# File not found for simulation 5, timestep 138, skipping to the next timestep.
# File not found for simulation 5, timestep 139, skipping to the next timestep.
# File not found for simulation 5, timestep 140, skipping to the next timestep.
# File not found for simulation 5, timestep 141, skipping to the next timestep.
# File not found for simulation 5, timestep 142, skipping to the next timestep.
# File not found for simulation 5, timestep 143, skipping to the next timestep.
# File not found for simulation 5, timestep 144, skipping to the next timestep.
# File not found for simulation 5, timestep 145, skipping to the next timestep.
# File not found for simulation 5, timestep 146, skipping to the next timestep.
# File not found for simulation 5, timestep 147, skipping to the next timestep.
# File not found for simulation 5, timestep 148, skipping to the next timestep.
# File not found for simulation 5, timestep 149, skipping to the next timestep.
# File not found for simulation 5, timestep 150, skipping to the next timestep.
# File not found for simulation 5, timestep 151, skipping to the next timestep.
# File not found for simulation 5, timestep 152, skipping to the next timestep.
# File not found for simulation 5, timestep 153, skipping to the next timestep.
# File not found for simulation 5, timestep 154, skipping to the next timestep.
# File not found for simulation 5, timestep 155, skipping to the next timestep.
# File not found for simulation 5, timestep 156, skipping to the next timestep.
# File not found for simulation 5, timestep 157, skipping to the next timestep.
# File not found for simulation 5, timestep 158, skipping to the next timestep.
# File not found for simulation 5, timestep 159, skipping to the next timestep.
# File not found for simulation 5, timestep 160, skipping to the next timestep.
# File not found for simulation 5, timestep 161, skipping to the next timestep.
# File not found for simulation 5, timestep 162, skipping to the next timestep.
# File not found for simulation 5, timestep 163, skipping to the next timestep.
# File not found for simulation 5, timestep 164, skipping to the next timestep.
# File not found for simulation 5, timestep 165, skipping to the next timestep.
# File not found for simulation 5, timestep 166, skipping to the next timestep.
# File not found for simulation 5, timestep 167, skipping to the next timestep.
# File not found for simulation 5, timestep 168, skipping to the next timestep.
# File not found for simulation 5, timestep 169, skipping to the next timestep.
# File not found for simulation 5, timestep 170, skipping to the next timestep.
# File not found for simulation 5, timestep 171, skipping to the next timestep.
# File not found for simulation 5, timestep 172, skipping to the next timestep.
# File not found for simulation 5, timestep 173, skipping to the next timestep.
# File not found for simulation 5, timestep 174, skipping to the next timestep.
# File not found for simulation 5, timestep 175, skipping to the next timestep.
# File not found for simulation 5, timestep 176, skipping to the next timestep.
# File not found for simulation 5, timestep 177, skipping to the next timestep.
# File not found for simulation 5, timestep 178, skipping to the next timestep.
# File not found for simulation 5, timestep 179, skipping to the next timestep.
# File not found for simulation 5, timestep 180, skipping to the next timestep.
# File not found for simulation 5, timestep 181, skipping to the next timestep.
# File not found for simulation 5, timestep 182, skipping to the next timestep.
# File not found for simulation 5, timestep 183, skipping to the next timestep.
# File not found for simulation 5, timestep 184, skipping to the next timestep.
# File not found for simulation 5, timestep 185, skipping to the next timestep.
# File not found for simulation 5, timestep 186, skipping to the next timestep.
# File not found for simulation 5, timestep 187, skipping to the next timestep.
# File not found for simulation 5, timestep 188, skipping to the next timestep.
# File not found for simulation 5, timestep 189, skipping to the next timestep.
# File not found for simulation 5, timestep 190, skipping to the next timestep.
# File not found for simulation 5, timestep 191, skipping to the next timestep.
# File not found for simulation 5, timestep 192, skipping to the next timestep.
# File not found for simulation 5, timestep 193, skipping to the next timestep.
# File not found for simulation 5, timestep 194, skipping to the next timestep.
# File not found for simulation 5, timestep 195, skipping to the next timestep.
# File not found for simulation 5, timestep 196, skipping to the next timestep.
# File not found for simulation 5, timestep 197, skipping to the next timestep.
# File not found for simulation 5, timestep 198, skipping to the next timestep.
# File not found for simulation 5, timestep 199, skipping to the next timestep.
# File not found for simulation 5, timestep 200, skipping to the next timestep.
# File not found for simulation 5, timestep 201, skipping to the next timestep.
# File not found for simulation 5, timestep 202, skipping to the next timestep.
# File not found for simulation 5, timestep 203, skipping to the next timestep.
# File not found for simulation 5, timestep 204, skipping to the next timestep.
# File not found for simulation 5, timestep 205, skipping to the next timestep.
# File not found for simulation 5, timestep 206, skipping to the next timestep.
# File not found for simulation 5, timestep 207, skipping to the next timestep.
# File not found for simulation 5, timestep 208, skipping to the next timestep.
# File not found for simulation 5, timestep 209, skipping to the next timestep.
# File not found for simulation 5, timestep 210, skipping to the next timestep.
# File not found for simulation 5, timestep 211, skipping to the next timestep.
# File not found for simulation 5, timestep 212, skipping to the next timestep.
# File not found for simulation 5, timestep 213, skipping to the next timestep.
# File not found for simulation 5, timestep 214, skipping to the next timestep.
# File not found for simulation 5, timestep 215, skipping to the next timestep.
# File not found for simulation 5, timestep 216, skipping to the next timestep.
# File not found for simulation 5, timestep 217, skipping to the next timestep.
# File not found for simulation 5, timestep 218, skipping to the next timestep.
# File not found for simulation 5, timestep 219, skipping to the next timestep.
# File not found for simulation 5, timestep 220, skipping to the next timestep.
# File not found for simulation 5, timestep 221, skipping to the next timestep.
# File not found for simulation 5, timestep 222, skipping to the next timestep.
# File not found for simulation 5, timestep 223, skipping to the next timestep.
# File not found for simulation 5, timestep 224, skipping to the next timestep.
# File not found for simulation 5, timestep 225, skipping to the next timestep.
# File not found for simulation 5, timestep 226, skipping to the next timestep.
# File not found for simulation 5, timestep 227, skipping to the next timestep.
# File not found for simulation 5, timestep 228, skipping to the next timestep.
# File not found for simulation 5, timestep 229, skipping to the next timestep.
# File not found for simulation 5, timestep 230, skipping to the next timestep.
# File not found for simulation 5, timestep 231, skipping to the next timestep.
# File not found for simulation 5, timestep 232, skipping to the next timestep.
# File not found for simulation 5, timestep 233, skipping to the next timestep.
# File not found for simulation 5, timestep 234, skipping to the next timestep.
# File not found for simulation 5, timestep 235, skipping to the next timestep.
# File not found for simulation 5, timestep 236, skipping to the next timestep.
# File not found for simulation 5, timestep 237, skipping to the next timestep.
# File not found for simulation 5, timestep 238, skipping to the next timestep.
# File not found for simulation 5, timestep 239, skipping to the next timestep.
# File not found for simulation 5, timestep 240, skipping to the next timestep.
# File not found for simulation 5, timestep 241, skipping to the next timestep.
# File not found for simulation 5, timestep 242, skipping to the next timestep.
# File not found for simulation 5, timestep 243, skipping to the next timestep.
# File not found for simulation 5, timestep 244, skipping to the next timestep.
# File not found for simulation 5, timestep 245, skipping to the next timestep.
# File not found for simulation 5, timestep 246, skipping to the next timestep.
# File not found for simulation 5, timestep 247, skipping to the next timestep.
# File not found for simulation 5, timestep 248, skipping to the next timestep.
# File not found for simulation 5, timestep 249, skipping to the next timestep.
# File not found for simulation 5, timestep 250, skipping to the next timestep.
# File not found for simulation 5, timestep 251, skipping to the next timestep.
# File not found for simulation 5, timestep 252, skipping to the next timestep.
# File not found for simulation 5, timestep 253, skipping to the next timestep.
# File not found for simulation 5, timestep 254, skipping to the next timestep.
# File not found for simulation 5, timestep 255, skipping to the next timestep.
# File not found for simulation 5, timestep 256, skipping to the next timestep.
# File not found for simulation 5, timestep 257, skipping to the next timestep.
# File not found for simulation 5, timestep 258, skipping to the next timestep.
# File not found for simulation 5, timestep 259, skipping to the next timestep.
# File not found for simulation 5, timestep 260, skipping to the next timestep.
# File not found for simulation 5, timestep 261, skipping to the next timestep.
# File not found for simulation 5, timestep 262, skipping to the next timestep.
# File not found for simulation 5, timestep 263, skipping to the next timestep.
# File not found for simulation 5, timestep 264, skipping to the next timestep.
# File not found for simulation 5, timestep 265, skipping to the next timestep.
# File not found for simulation 5, timestep 266, skipping to the next timestep.
# File not found for simulation 5, timestep 267, skipping to the next timestep.
# File not found for simulation 5, timestep 268, skipping to the next timestep.
# File not found for simulation 5, timestep 269, skipping to the next timestep.
# File not found for simulation 5, timestep 270, skipping to the next timestep.
# File not found for simulation 5, timestep 271, skipping to the next timestep.
# File not found for simulation 5, timestep 272, skipping to the next timestep.
# File not found for simulation 5, timestep 273, skipping to the next timestep.
# File not found for simulation 5, timestep 274, skipping to the next timestep.
# File not found for simulation 5, timestep 275, skipping to the next timestep.
# File not found for simulation 5, timestep 276, skipping to the next timestep.
# File not found for simulation 5, timestep 277, skipping to the next timestep.
# File not found for simulation 5, timestep 278, skipping to the next timestep.
# File not found for simulation 5, timestep 279, skipping to the next timestep.
# File not found for simulation 5, timestep 280, skipping to the next timestep.
# File not found for simulation 5, timestep 281, skipping to the next timestep.
# File not found for simulation 5, timestep 282, skipping to the next timestep.
# File not found for simulation 5, timestep 283, skipping to the next timestep.
# File not found for simulation 5, timestep 284, skipping to the next timestep.
# File not found for simulation 5, timestep 285, skipping to the next timestep.
# File not found for simulation 5, timestep 286, skipping to the next timestep.
# File not found for simulation 5, timestep 287, skipping to the next timestep.
# File not found for simulation 5, timestep 288, skipping to the next timestep.
# File not found for simulation 5, timestep 289, skipping to the next timestep.
# File not found for simulation 5, timestep 290, skipping to the next timestep.
# File not found for simulation 5, timestep 291, skipping to the next timestep.
# File not found for simulation 5, timestep 292, skipping to the next timestep.
# File not found for simulation 5, timestep 293, skipping to the next timestep.
# File not found for simulation 5, timestep 294, skipping to the next timestep.
# File not found for simulation 5, timestep 295, skipping to the next timestep.
# File not found for simulation 5, timestep 296, skipping to the next timestep.
# File not found for simulation 5, timestep 297, skipping to the next timestep.
# File not found for simulation 5, timestep 298, skipping to the next timestep.
# File not found for simulation 5, timestep 299, skipping to the next timestep.
# File not found for simulation 5, timestep 300, skipping to the next timestep.
# File not found for simulation 5, timestep 301, skipping to the next timestep.
# File not found for simulation 5, timestep 302, skipping to the next timestep.
# File not found for simulation 5, timestep 303, skipping to the next timestep.
# File not found for simulation 5, timestep 304, skipping to the next timestep.
# File not found for simulation 5, timestep 305, skipping to the next timestep.
# File not found for simulation 5, timestep 306, skipping to the next timestep.
# File not found for simulation 5, timestep 307, skipping to the next timestep.
# File not found for simulation 5, timestep 308, skipping to the next timestep.
# File not found for simulation 5, timestep 309, skipping to the next timestep.
# File not found for simulation 5, timestep 310, skipping to the next timestep.
# File not found for simulation 5, timestep 311, skipping to the next timestep.
# File not found for simulation 5, timestep 312, skipping to the next timestep.
# File not found for simulation 5, timestep 313, skipping to the next timestep.
# File not found for simulation 5, timestep 314, skipping to the next timestep.
# File not found for simulation 5, timestep 315, skipping to the next timestep.
# File not found for simulation 5, timestep 316, skipping to the next timestep.
# File not found for simulation 5, timestep 317, skipping to the next timestep.
# File not found for simulation 5, timestep 318, skipping to the next timestep.
# File not found for simulation 5, timestep 319, skipping to the next timestep.
# File not found for simulation 5, timestep 320, skipping to the next timestep.
# File not found for simulation 5, timestep 321, skipping to the next timestep.
# File not found for simulation 5, timestep 322, skipping to the next timestep.
# File not found for simulation 5, timestep 323, skipping to the next timestep.
# File not found for simulation 5, timestep 324, skipping to the next timestep.
# File not found for simulation 5, timestep 325, skipping to the next timestep.
# File not found for simulation 5, timestep 326, skipping to the next timestep.
# File not found for simulation 5, timestep 327, skipping to the next timestep.
# File not found for simulation 5, timestep 328, skipping to the next timestep.
# File not found for simulation 5, timestep 329, skipping to the next timestep.
# File not found for simulation 5, timestep 330, skipping to the next timestep.
# File not found for simulation 5, timestep 331, skipping to the next timestep.
# File not found for simulation 5, timestep 332, skipping to the next timestep.
# File not found for simulation 5, timestep 333, skipping to the next timestep.
# File not found for simulation 5, timestep 334, skipping to the next timestep.
# File not found for simulation 5, timestep 335, skipping to the next timestep.
# File not found for simulation 5, timestep 336, skipping to the next timestep.
# File not found for simulation 5, timestep 337, skipping to the next timestep.
# File not found for simulation 5, timestep 338, skipping to the next timestep.
# File not found for simulation 5, timestep 339, skipping to the next timestep.
# File not found for simulation 5, timestep 340, skipping to the next timestep.
# File not found for simulation 5, timestep 341, skipping to the next timestep.
# File not found for simulation 5, timestep 342, skipping to the next timestep.
# File not found for simulation 5, timestep 343, skipping to the next timestep.
# File not found for simulation 5, timestep 344, skipping to the next timestep.
# File not found for simulation 5, timestep 345, skipping to the next timestep.
# File not found for simulation 5, timestep 346, skipping to the next timestep.
# File not found for simulation 5, timestep 347, skipping to the next timestep.
# File not found for simulation 5, timestep 348, skipping to the next timestep.
# File not found for simulation 5, timestep 349, skipping to the next timestep.
# File not found for simulation 5, timestep 350, skipping to the next timestep.
# File not found for simulation 5, timestep 351, skipping to the next timestep.
# File not found for simulation 5, timestep 352, skipping to the next timestep.
# File not found for simulation 5, timestep 353, skipping to the next timestep.
# File not found for simulation 5, timestep 354, skipping to the next timestep.
# File not found for simulation 5, timestep 355, skipping to the next timestep.
# File not found for simulation 5, timestep 356, skipping to the next timestep.
# File not found for simulation 5, timestep 357, skipping to the next timestep.
# File not found for simulation 5, timestep 358, skipping to the next timestep.
# File not found for simulation 5, timestep 359, skipping to the next timestep.
# File not found for simulation 5, timestep 360, skipping to the next timestep.
# File not found for simulation 5, timestep 361, skipping to the next timestep.
# File not found for simulation 5, timestep 362, skipping to the next timestep.
# File not found for simulation 5, timestep 363, skipping to the next timestep.
# File not found for simulation 5, timestep 364, skipping to the next timestep.
# File not found for simulation 5, timestep 365, skipping to the next timestep.
# File not found for simulation 5, timestep 366, skipping to the next timestep.
# File not found for simulation 5, timestep 367, skipping to the next timestep.
# File not found for simulation 5, timestep 368, skipping to the next timestep.
# File not found for simulation 5, timestep 369, skipping to the next timestep.
# File not found for simulation 5, timestep 370, skipping to the next timestep.
# File not found for simulation 5, timestep 371, skipping to the next timestep.
# File not found for simulation 5, timestep 372, skipping to the next timestep.
# File not found for simulation 5, timestep 373, skipping to the next timestep.
# File not found for simulation 5, timestep 374, skipping to the next timestep.
# File not found for simulation 5, timestep 375, skipping to the next timestep.
# File not found for simulation 5, timestep 376, skipping to the next timestep.
# File not found for simulation 5, timestep 377, skipping to the next timestep.
# File not found for simulation 5, timestep 378, skipping to the next timestep.
# File not found for simulation 5, timestep 379, skipping to the next timestep.
# File not found for simulation 5, timestep 380, skipping to the next timestep.
# File not found for simulation 5, timestep 381, skipping to the next timestep.
# File not found for simulation 5, timestep 382, skipping to the next timestep.
# File not found for simulation 5, timestep 383, skipping to the next timestep.
# File not found for simulation 5, timestep 384, skipping to the next timestep.
# File not found for simulation 5, timestep 385, skipping to the next timestep.
# File not found for simulation 5, timestep 386, skipping to the next timestep.
# File not found for simulation 5, timestep 387, skipping to the next timestep.
# File not found for simulation 5, timestep 388, skipping to the next timestep.
# File not found for simulation 5, timestep 389, skipping to the next timestep.
# File not found for simulation 5, timestep 390, skipping to the next timestep.
# File not found for simulation 5, timestep 391, skipping to the next timestep.
# File not found for simulation 5, timestep 392, skipping to the next timestep.
# File not found for simulation 5, timestep 393, skipping to the next timestep.
# File not found for simulation 5, timestep 394, skipping to the next timestep.
# File not found for simulation 5, timestep 395, skipping to the next timestep.
# File not found for simulation 5, timestep 396, skipping to the next timestep.
# File not found for simulation 5, timestep 397, skipping to the next timestep.
# File not found for simulation 5, timestep 398, skipping to the next timestep.
# File not found for simulation 5, timestep 399, skipping to the next timestep.
# File not found for simulation 5, timestep 400, skipping to the next timestep.
# File not found for simulation 5, timestep 401, skipping to the next timestep.
# File not found for simulation 5, timestep 402, skipping to the next timestep.
# File not found for simulation 5, timestep 403, skipping to the next timestep.
# File not found for simulation 5, timestep 404, skipping to the next timestep.
# File not found for simulation 5, timestep 405, skipping to the next timestep.
# File not found for simulation 5, timestep 406, skipping to the next timestep.
# File not found for simulation 5, timestep 407, skipping to the next timestep.
# File not found for simulation 5, timestep 408, skipping to the next timestep.
# File not found for simulation 5, timestep 409, skipping to the next timestep.
# File not found for simulation 5, timestep 410, skipping to the next timestep.
# File not found for simulation 5, timestep 411, skipping to the next timestep.
# File not found for simulation 5, timestep 412, skipping to the next timestep.
# File not found for simulation 5, timestep 413, skipping to the next timestep.
# File not found for simulation 5, timestep 414, skipping to the next timestep.
# File not found for simulation 5, timestep 415, skipping to the next timestep.
# File not found for simulation 5, timestep 416, skipping to the next timestep.
# File not found for simulation 5, timestep 417, skipping to the next timestep.
# File not found for simulation 5, timestep 418, skipping to the next timestep.
# File not found for simulation 5, timestep 419, skipping to the next timestep.
# File not found for simulation 5, timestep 420, skipping to the next timestep.
# File not found for simulation 5, timestep 421, skipping to the next timestep.
# File not found for simulation 5, timestep 422, skipping to the next timestep.
# File not found for simulation 5, timestep 423, skipping to the next timestep.
# File not found for simulation 5, timestep 424, skipping to the next timestep.
# File not found for simulation 5, timestep 425, skipping to the next timestep.
# File not found for simulation 5, timestep 426, skipping to the next timestep.
# File not found for simulation 5, timestep 427, skipping to the next timestep.
# File not found for simulation 5, timestep 428, skipping to the next timestep.
# File not found for simulation 5, timestep 429, skipping to the next timestep.
# File not found for simulation 5, timestep 430, skipping to the next timestep.
# File not found for simulation 5, timestep 431, skipping to the next timestep.
# File not found for simulation 5, timestep 432, skipping to the next timestep.
# File not found for simulation 5, timestep 433, skipping to the next timestep.
# File not found for simulation 5, timestep 434, skipping to the next timestep.
# File not found for simulation 5, timestep 435, skipping to the next timestep.
# File not found for simulation 5, timestep 436, skipping to the next timestep.
# File not found for simulation 5, timestep 437, skipping to the next timestep.
# File not found for simulation 5, timestep 438, skipping to the next timestep.
# File not found for simulation 5, timestep 439, skipping to the next timestep.
# File not found for simulation 5, timestep 440, skipping to the next timestep.
# File not found for simulation 5, timestep 441, skipping to the next timestep.
# File not found for simulation 5, timestep 442, skipping to the next timestep.
# File not found for simulation 5, timestep 443, skipping to the next timestep.
# File not found for simulation 5, timestep 444, skipping to the next timestep.
# File not found for simulation 5, timestep 445, skipping to the next timestep.
# File not found for simulation 5, timestep 446, skipping to the next timestep.
# File not found for simulation 5, timestep 447, skipping to the next timestep.
# File not found for simulation 5, timestep 448, skipping to the next timestep.
# File not found for simulation 5, timestep 449, skipping to the next timestep.
# File not found for simulation 5, timestep 450, skipping to the next timestep.
# File not found for simulation 5, timestep 451, skipping to the next timestep.
# File not found for simulation 5, timestep 452, skipping to the next timestep.
# File not found for simulation 5, timestep 453, skipping to the next timestep.
# File not found for simulation 5, timestep 454, skipping to the next timestep.
# File not found for simulation 5, timestep 455, skipping to the next timestep.
# File not found for simulation 5, timestep 456, skipping to the next timestep.
# File not found for simulation 5, timestep 457, skipping to the next timestep.
# File not found for simulation 5, timestep 458, skipping to the next timestep.
# File not found for simulation 5, timestep 459, skipping to the next timestep.
# File not found for simulation 5, timestep 460, skipping to the next timestep.
# File not found for simulation 5, timestep 461, skipping to the next timestep.
# File not found for simulation 5, timestep 462, skipping to the next timestep.
# File not found for simulation 5, timestep 463, skipping to the next timestep.
# File not found for simulation 5, timestep 464, skipping to the next timestep.
# File not found for simulation 5, timestep 465, skipping to the next timestep.
# File not found for simulation 5, timestep 466, skipping to the next timestep.
# File not found for simulation 5, timestep 467, skipping to the next timestep.
# File not found for simulation 5, timestep 468, skipping to the next timestep.
# File not found for simulation 5, timestep 469, skipping to the next timestep.
# File not found for simulation 5, timestep 470, skipping to the next timestep.
# File not found for simulation 5, timestep 471, skipping to the next timestep.
# File not found for simulation 5, timestep 472, skipping to the next timestep.
# File not found for simulation 5, timestep 473, skipping to the next timestep.
# File not found for simulation 5, timestep 474, skipping to the next timestep.
# File not found for simulation 5, timestep 475, skipping to the next timestep.
# File not found for simulation 5, timestep 476, skipping to the next timestep.
# File not found for simulation 5, timestep 477, skipping to the next timestep.
# File not found for simulation 5, timestep 478, skipping to the next timestep.
# File not found for simulation 5, timestep 479, skipping to the next timestep.
# File not found for simulation 5, timestep 480, skipping to the next timestep.
# File not found for simulation 5, timestep 481, skipping to the next timestep.
# File not found for simulation 5, timestep 482, skipping to the next timestep.
# File not found for simulation 5, timestep 483, skipping to the next timestep.
# File not found for simulation 5, timestep 484, skipping to the next timestep.
# File not found for simulation 5, timestep 485, skipping to the next timestep.
# File not found for simulation 5, timestep 486, skipping to the next timestep.
# File not found for simulation 5, timestep 487, skipping to the next timestep.
# File not found for simulation 5, timestep 488, skipping to the next timestep.
# File not found for simulation 5, timestep 489, skipping to the next timestep.
# File not found for simulation 5, timestep 490, skipping to the next timestep.
# File not found for simulation 5, timestep 491, skipping to the next timestep.
# File not found for simulation 5, timestep 492, skipping to the next timestep.
# File not found for simulation 5, timestep 493, skipping to the next timestep.
# File not found for simulation 5, timestep 494, skipping to the next timestep.
# File not found for simulation 5, timestep 495, skipping to the next timestep.
# File not found for simulation 5, timestep 496, skipping to the next timestep.
# File not found for simulation 5, timestep 497, skipping to the next timestep.
# File not found for simulation 5, timestep 498, skipping to the next timestep.
# File not found for simulation 5, timestep 499, skipping to the next timestep.
# File not found for simulation 5, timestep 500, skipping to the next timestep.
# File not found for simulation 5, timestep 501, skipping to the next timestep.
# File not found for simulation 5, timestep 502, skipping to the next timestep.
# File not found for simulation 5, timestep 503, skipping to the next timestep.
# File not found for simulation 5, timestep 504, skipping to the next timestep.
# File not found for simulation 5, timestep 505, skipping to the next timestep.
# File not found for simulation 5, timestep 506, skipping to the next timestep.
# File not found for simulation 5, timestep 507, skipping to the next timestep.
# File not found for simulation 5, timestep 508, skipping to the next timestep.
# File not found for simulation 5, timestep 509, skipping to the next timestep.
# File not found for simulation 5, timestep 510, skipping to the next timestep.
# File not found for simulation 5, timestep 511, skipping to the next timestep.
# File not found for simulation 5, timestep 512, skipping to the next timestep.
# File not found for simulation 5, timestep 513, skipping to the next timestep.
# File not found for simulation 5, timestep 514, skipping to the next timestep.
# File not found for simulation 5, timestep 515, skipping to the next timestep.
# File not found for simulation 5, timestep 516, skipping to the next timestep.
# File not found for simulation 5, timestep 517, skipping to the next timestep.
# File not found for simulation 5, timestep 518, skipping to the next timestep.
# File not found for simulation 5, timestep 519, skipping to the next timestep.
# File not found for simulation 5, timestep 520, skipping to the next timestep.
# File not found for simulation 5, timestep 521, skipping to the next timestep.
# File not found for simulation 5, timestep 522, skipping to the next timestep.
# File not found for simulation 5, timestep 523, skipping to the next timestep.
# File not found for simulation 5, timestep 524, skipping to the next timestep.
# File not found for simulation 5, timestep 525, skipping to the next timestep.
# File not found for simulation 5, timestep 526, skipping to the next timestep.
# File not found for simulation 5, timestep 527, skipping to the next timestep.
# File not found for simulation 5, timestep 528, skipping to the next timestep.
# File not found for simulation 5, timestep 529, skipping to the next timestep.
# File not found for simulation 5, timestep 530, skipping to the next timestep.
# File not found for simulation 5, timestep 531, skipping to the next timestep.
# File not found for simulation 5, timestep 532, skipping to the next timestep.
# File not found for simulation 5, timestep 533, skipping to the next timestep.
# File not found for simulation 5, timestep 534, skipping to the next timestep.
# File not found for simulation 5, timestep 535, skipping to the next timestep.
# File not found for simulation 5, timestep 536, skipping to the next timestep.
# File not found for simulation 5, timestep 537, skipping to the next timestep.
# File not found for simulation 5, timestep 538, skipping to the next timestep.
# File not found for simulation 5, timestep 539, skipping to the next timestep.
# File not found for simulation 5, timestep 540, skipping to the next timestep.
# File not found for simulation 5, timestep 541, skipping to the next timestep.
# File not found for simulation 5, timestep 542, skipping to the next timestep.
# File not found for simulation 5, timestep 543, skipping to the next timestep.
# File not found for simulation 5, timestep 544, skipping to the next timestep.
# File not found for simulation 5, timestep 545, skipping to the next timestep.
# File not found for simulation 5, timestep 546, skipping to the next timestep.
# File not found for simulation 5, timestep 547, skipping to the next timestep.
# File not found for simulation 5, timestep 548, skipping to the next timestep.
# File not found for simulation 5, timestep 549, skipping to the next timestep.
# File not found for simulation 5, timestep 550, skipping to the next timestep.
# File not found for simulation 5, timestep 551, skipping to the next timestep.
# File not found for simulation 5, timestep 552, skipping to the next timestep.
# File not found for simulation 5, timestep 553, skipping to the next timestep.
# File not found for simulation 5, timestep 554, skipping to the next timestep.
# File not found for simulation 5, timestep 555, skipping to the next timestep.
# File not found for simulation 5, timestep 556, skipping to the next timestep.
# File not found for simulation 5, timestep 557, skipping to the next timestep.
# File not found for simulation 5, timestep 558, skipping to the next timestep.
# File not found for simulation 5, timestep 559, skipping to the next timestep.
# File not found for simulation 5, timestep 560, skipping to the next timestep.
# File not found for simulation 5, timestep 561, skipping to the next timestep.
# File not found for simulation 5, timestep 562, skipping to the next timestep.
# File not found for simulation 5, timestep 563, skipping to the next timestep.
# File not found for simulation 5, timestep 564, skipping to the next timestep.
# File not found for simulation 5, timestep 565, skipping to the next timestep.
# File not found for simulation 5, timestep 566, skipping to the next timestep.
# File not found for simulation 5, timestep 567, skipping to the next timestep.
# File not found for simulation 5, timestep 568, skipping to the next timestep.
# File not found for simulation 5, timestep 569, skipping to the next timestep.
# File not found for simulation 5, timestep 570, skipping to the next timestep.
# File not found for simulation 5, timestep 571, skipping to the next timestep.
# File not found for simulation 5, timestep 572, skipping to the next timestep.
# File not found for simulation 5, timestep 573, skipping to the next timestep.
# File not found for simulation 5, timestep 574, skipping to the next timestep.
# File not found for simulation 5, timestep 575, skipping to the next timestep.
# File not found for simulation 5, timestep 576, skipping to the next timestep.
# File not found for simulation 5, timestep 577, skipping to the next timestep.
# File not found for simulation 5, timestep 578, skipping to the next timestep.
# File not found for simulation 5, timestep 579, skipping to the next timestep.
# File not found for simulation 5, timestep 580, skipping to the next timestep.
# File not found for simulation 5, timestep 581, skipping to the next timestep.
# File not found for simulation 5, timestep 582, skipping to the next timestep.
# File not found for simulation 5, timestep 583, skipping to the next timestep.
# File not found for simulation 5, timestep 584, skipping to the next timestep.
# File not found for simulation 5, timestep 585, skipping to the next timestep.
# File not found for simulation 5, timestep 586, skipping to the next timestep.
# File not found for simulation 5, timestep 587, skipping to the next timestep.
# File not found for simulation 5, timestep 588, skipping to the next timestep.
# File not found for simulation 5, timestep 589, skipping to the next timestep.
# File not found for simulation 5, timestep 590, skipping to the next timestep.
# File not found for simulation 5, timestep 591, skipping to the next timestep.
# File not found for simulation 5, timestep 592, skipping to the next timestep.
# File not found for simulation 5, timestep 593, skipping to the next timestep.
# File not found for simulation 5, timestep 594, skipping to the next timestep.
# File not found for simulation 5, timestep 595, skipping to the next timestep.
# File not found for simulation 5, timestep 596, skipping to the next timestep.
# File not found for simulation 5, timestep 597, skipping to the next timestep.
# File not found for simulation 5, timestep 598, skipping to the next timestep.
# File not found for simulation 5, timestep 599, skipping to the next timestep.
# File not found for simulation 5, timestep 600, skipping to the next timestep.
# File not found for simulation 5, timestep 601, skipping to the next timestep.
# File not found for simulation 5, timestep 602, skipping to the next timestep.
# File not found for simulation 5, timestep 603, skipping to the next timestep.
# File not found for simulation 5, timestep 604, skipping to the next timestep.
# File not found for simulation 5, timestep 605, skipping to the next timestep.
# File not found for simulation 5, timestep 606, skipping to the next timestep.
# File not found for simulation 5, timestep 607, skipping to the next timestep.
# File not found for simulation 5, timestep 608, skipping to the next timestep.
# File not found for simulation 5, timestep 609, skipping to the next timestep.
# File not found for simulation 5, timestep 610, skipping to the next timestep.
# File not found for simulation 5, timestep 611, skipping to the next timestep.
# File not found for simulation 5, timestep 612, skipping to the next timestep.
# File not found for simulation 5, timestep 613, skipping to the next timestep.
# File not found for simulation 5, timestep 614, skipping to the next timestep.
# File not found for simulation 5, timestep 615, skipping to the next timestep.
# File not found for simulation 5, timestep 616, skipping to the next timestep.
# File not found for simulation 5, timestep 617, skipping to the next timestep.
# File not found for simulation 5, timestep 618, skipping to the next timestep.
# File not found for simulation 5, timestep 619, skipping to the next timestep.
# File not found for simulation 5, timestep 620, skipping to the next timestep.
# File not found for simulation 5, timestep 621, skipping to the next timestep.
# File not found for simulation 5, timestep 622, skipping to the next timestep.
# File not found for simulation 5, timestep 623, skipping to the next timestep.
# File not found for simulation 5, timestep 624, skipping to the next timestep.
# File not found for simulation 5, timestep 625, skipping to the next timestep.
# File not found for simulation 5, timestep 626, skipping to the next timestep.
# File not found for simulation 5, timestep 627, skipping to the next timestep.
# File not found for simulation 5, timestep 628, skipping to the next timestep.
# File not found for simulation 5, timestep 629, skipping to the next timestep.
# File not found for simulation 5, timestep 630, skipping to the next timestep.
# File not found for simulation 5, timestep 631, skipping to the next timestep.
# File not found for simulation 5, timestep 632, skipping to the next timestep.
# File not found for simulation 5, timestep 633, skipping to the next timestep.
# File not found for simulation 5, timestep 634, skipping to the next timestep.
# File not found for simulation 5, timestep 635, skipping to the next timestep.
# File not found for simulation 5, timestep 636, skipping to the next timestep.
# File not found for simulation 5, timestep 637, skipping to the next timestep.
# File not found for simulation 5, timestep 638, skipping to the next timestep.
# File not found for simulation 5, timestep 639, skipping to the next timestep.
# File not found for simulation 5, timestep 640, skipping to the next timestep.
# File not found for simulation 5, timestep 641, skipping to the next timestep.
# File not found for simulation 5, timestep 642, skipping to the next timestep.
# File not found for simulation 5, timestep 643, skipping to the next timestep.
# File not found for simulation 5, timestep 644, skipping to the next timestep.
# File not found for simulation 5, timestep 645, skipping to the next timestep.
# File not found for simulation 5, timestep 646, skipping to the next timestep.
# File not found for simulation 5, timestep 647, skipping to the next timestep.
# File not found for simulation 5, timestep 648, skipping to the next timestep.
# File not found for simulation 5, timestep 649, skipping to the next timestep.
# File not found for simulation 5, timestep 650, skipping to the next timestep.
# File not found for simulation 5, timestep 651, skipping to the next timestep.
# File not found for simulation 5, timestep 652, skipping to the next timestep.
# File not found for simulation 5, timestep 653, skipping to the next timestep.
# File not found for simulation 5, timestep 654, skipping to the next timestep.
# File not found for simulation 5, timestep 655, skipping to the next timestep.
# File not found for simulation 5, timestep 656, skipping to the next timestep.
# File not found for simulation 5, timestep 657, skipping to the next timestep.
# File not found for simulation 5, timestep 658, skipping to the next timestep.
# File not found for simulation 5, timestep 659, skipping to the next timestep.
# File not found for simulation 5, timestep 660, skipping to the next timestep.
# File not found for simulation 5, timestep 661, skipping to the next timestep.
# File not found for simulation 5, timestep 662, skipping to the next timestep.
# File not found for simulation 5, timestep 663, skipping to the next timestep.
# File not found for simulation 5, timestep 664, skipping to the next timestep.
# File not found for simulation 5, timestep 665, skipping to the next timestep.
# File not found for simulation 5, timestep 666, skipping to the next timestep.
# File not found for simulation 5, timestep 667, skipping to the next timestep.
# File not found for simulation 5, timestep 668, skipping to the next timestep.
# File not found for simulation 5, timestep 669, skipping to the next timestep.
# File not found for simulation 5, timestep 670, skipping to the next timestep.
# File not found for simulation 5, timestep 671, skipping to the next timestep.
# File not found for simulation 5, timestep 672, skipping to the next timestep.
# File not found for simulation 5, timestep 673, skipping to the next timestep.
# File not found for simulation 5, timestep 674, skipping to the next timestep.
# File not found for simulation 5, timestep 675, skipping to the next timestep.
# File not found for simulation 5, timestep 676, skipping to the next timestep.
# File not found for simulation 5, timestep 677, skipping to the next timestep.
# File not found for simulation 5, timestep 678, skipping to the next timestep.
# File not found for simulation 5, timestep 679, skipping to the next timestep.
# File not found for simulation 5, timestep 680, skipping to the next timestep.
# File not found for simulation 5, timestep 681, skipping to the next timestep.
# File not found for simulation 5, timestep 682, skipping to the next timestep.
# File not found for simulation 5, timestep 683, skipping to the next timestep.
# File not found for simulation 5, timestep 684, skipping to the next timestep.
# File not found for simulation 5, timestep 685, skipping to the next timestep.
# File not found for simulation 5, timestep 686, skipping to the next timestep.
# File not found for simulation 5, timestep 687, skipping to the next timestep.
# File not found for simulation 5, timestep 688, skipping to the next timestep.
# File not found for simulation 5, timestep 689, skipping to the next timestep.
# File not found for simulation 5, timestep 690, skipping to the next timestep.
# File not found for simulation 5, timestep 691, skipping to the next timestep.
# File not found for simulation 5, timestep 692, skipping to the next timestep.
# File not found for simulation 5, timestep 693, skipping to the next timestep.
# File not found for simulation 5, timestep 694, skipping to the next timestep.
# File not found for simulation 5, timestep 695, skipping to the next timestep.
# File not found for simulation 5, timestep 696, skipping to the next timestep.
# File not found for simulation 5, timestep 697, skipping to the next timestep.
# File not found for simulation 5, timestep 698, skipping to the next timestep.
# File not found for simulation 5, timestep 699, skipping to the next timestep.
# File not found for simulation 5, timestep 700, skipping to the next timestep.
# File not found for simulation 5, timestep 701, skipping to the next timestep.
# File not found for simulation 5, timestep 702, skipping to the next timestep.
# File not found for simulation 5, timestep 703, skipping to the next timestep.
# File not found for simulation 5, timestep 704, skipping to the next timestep.
# File not found for simulation 5, timestep 705, skipping to the next timestep.
# File not found for simulation 5, timestep 706, skipping to the next timestep.
# File not found for simulation 5, timestep 707, skipping to the next timestep.
# File not found for simulation 5, timestep 708, skipping to the next timestep.
# File not found for simulation 5, timestep 709, skipping to the next timestep.
# File not found for simulation 5, timestep 710, skipping to the next timestep.
# File not found for simulation 5, timestep 711, skipping to the next timestep.
# File not found for simulation 5, timestep 712, skipping to the next timestep.
# File not found for simulation 5, timestep 713, skipping to the next timestep.
# File not found for simulation 5, timestep 714, skipping to the next timestep.
# File not found for simulation 5, timestep 715, skipping to the next timestep.
# File not found for simulation 5, timestep 716, skipping to the next timestep.
# File not found for simulation 5, timestep 717, skipping to the next timestep.
# File not found for simulation 5, timestep 718, skipping to the next timestep.
# File not found for simulation 5, timestep 719, skipping to the next timestep.
# File not found for simulation 5, timestep 720, skipping to the next timestep.
# File not found for simulation 5, timestep 721, skipping to the next timestep.
# File not found for simulation 5, timestep 722, skipping to the next timestep.
# File not found for simulation 5, timestep 723, skipping to the next timestep.
# File not found for simulation 5, timestep 724, skipping to the next timestep.
# File not found for simulation 5, timestep 725, skipping to the next timestep.
# File not found for simulation 5, timestep 726, skipping to the next timestep.
# File not found for simulation 5, timestep 727, skipping to the next timestep.
# File not found for simulation 5, timestep 728, skipping to the next timestep.
# File not found for simulation 5, timestep 729, skipping to the next timestep.
# File not found for simulation 5, timestep 730, skipping to the next timestep.
# File not found for simulation 5, timestep 731, skipping to the next timestep.
# File not found for simulation 5, timestep 732, skipping to the next timestep.
# File not found for simulation 5, timestep 733, skipping to the next timestep.
# File not found for simulation 5, timestep 734, skipping to the next timestep.
# File not found for simulation 5, timestep 735, skipping to the next timestep.
# File not found for simulation 5, timestep 736, skipping to the next timestep.
# File not found for simulation 5, timestep 737, skipping to the next timestep.
# File not found for simulation 5, timestep 738, skipping to the next timestep.
# ...
# File not found for simulation 99, timestep 1808, skipping to the next timestep.
# File not found for simulation 99, timestep 1809, skipping to the next timestep.
# File not found for simulation 99, timestep 1810, skipping to the next timestep.
# File not found for simulation 99, timestep 1811, skipping to the next timestep.
# File not found for simulation 99, timestep 1812, skipping to the next timestep.
# File not found for simulation 99, timestep 1813, skipping to the next timestep.
# File not found for simulation 99, timestep 1814, skipping to the next timestep.
# File not found for simulation 99, timestep 1815, skipping to the next timestep.
# File not found for simulation 99, timestep 1816, skipping to the next timestep.
# File not found for simulation 99, timestep 1817, skipping to the next timestep.
# File not found for simulation 99, timestep 1818, skipping to the next timestep.
# File not found for simulation 99, timestep 1819, skipping to the next timestep.
# File not found for simulation 99, timestep 1820, skipping to the next timestep.
# File not found for simulation 99, timestep 1821, skipping to the next timestep.
# File not found for simulation 99, timestep 1822, skipping to the next timestep.
# File not found for simulation 99, timestep 1823, skipping to the next timestep.
# File not found for simulation 99, timestep 1824, skipping to the next timestep.
# File not found for simulation 99, timestep 1825, skipping to the next timestep.
# File not found for simulation 99, timestep 1826, skipping to the next timestep.
# File not found for simulation 99, timestep 1827, skipping to the next timestep.
# File not found for simulation 99, timestep 1828, skipping to the next timestep.
# File not found for simulation 99, timestep 1829, skipping to the next timestep.
# File not found for simulation 99, timestep 1830, skipping to the next timestep.
# File not found for simulation 99, timestep 1831, skipping to the next timestep.
# File not found for simulation 99, timestep 1832, skipping to the next timestep.
# File not found for simulation 99, timestep 1833, skipping to the next timestep.
# File not found for simulation 99, timestep 1834, skipping to the next timestep.
# File not found for simulation 99, timestep 1835, skipping to the next timestep.
# File not found for simulation 99, timestep 1836, skipping to the next timestep.
# File not found for simulation 99, timestep 1837, skipping to the next timestep.
# File not found for simulation 99, timestep 1838, skipping to the next timestep.
# File not found for simulation 99, timestep 1839, skipping to the next timestep.
# File not found for simulation 99, timestep 1840, skipping to the next timestep.
# File not found for simulation 99, timestep 1841, skipping to the next timestep.
# File not found for simulation 99, timestep 1842, skipping to the next timestep.
# File not found for simulation 99, timestep 1843, skipping to the next timestep.
# File not found for simulation 99, timestep 1844, skipping to the next timestep.
# File not found for simulation 99, timestep 1845, skipping to the next timestep.
# File not found for simulation 99, timestep 1846, skipping to the next timestep.
# File not found for simulation 99, timestep 1847, skipping to the next timestep.
# File not found for simulation 99, timestep 1848, skipping to the next timestep.
# File not found for simulation 99, timestep 1849, skipping to the next timestep.
# File not found for simulation 99, timestep 1850, skipping to the next timestep.
# File not found for simulation 99, timestep 1851, skipping to the next timestep.
# File not found for simulation 99, timestep 1852, skipping to the next timestep.
# File not found for simulation 99, timestep 1853, skipping to the next timestep.
# File not found for simulation 99, timestep 1854, skipping to the next timestep.
# File not found for simulation 99, timestep 1855, skipping to the next timestep.
# File not found for simulation 99, timestep 1856, skipping to the next timestep.
# File not found for simulation 99, timestep 1857, skipping to the next timestep.
# File not found for simulation 99, timestep 1858, skipping to the next timestep.
# File not found for simulation 99, timestep 1859, skipping to the next timestep.
# File not found for simulation 99, timestep 1860, skipping to the next timestep.
# File not found for simulation 99, timestep 1861, skipping to the next timestep.
# File not found for simulation 99, timestep 1862, skipping to the next timestep.
# File not found for simulation 99, timestep 1863, skipping to the next timestep.
# File not found for simulation 99, timestep 1864, skipping to the next timestep.
# File not found for simulation 99, timestep 1865, skipping to the next timestep.
# File not found for simulation 99, timestep 1866, skipping to the next timestep.
# File not found for simulation 99, timestep 1867, skipping to the next timestep.
# File not found for simulation 99, timestep 1868, skipping to the next timestep.
# File not found for simulation 99, timestep 1869, skipping to the next timestep.
# File not found for simulation 99, timestep 1870, skipping to the next timestep.
# File not found for simulation 99, timestep 1871, skipping to the next timestep.
# File not found for simulation 99, timestep 1872, skipping to the next timestep.
# File not found for simulation 99, timestep 1873, skipping to the next timestep.
# File not found for simulation 99, timestep 1874, skipping to the next timestep.
# File not found for simulation 99, timestep 1875, skipping to the next timestep.
# File not found for simulation 99, timestep 1876, skipping to the next timestep.
# File not found for simulation 99, timestep 1877, skipping to the next timestep.
# File not found for simulation 99, timestep 1878, skipping to the next timestep.
# File not found for simulation 99, timestep 1879, skipping to the next timestep.
# File not found for simulation 99, timestep 1880, skipping to the next timestep.
# File not found for simulation 99, timestep 1881, skipping to the next timestep.
# File not found for simulation 99, timestep 1882, skipping to the next timestep.
# File not found for simulation 99, timestep 1883, skipping to the next timestep.
# File not found for simulation 99, timestep 1884, skipping to the next timestep.
# File not found for simulation 99, timestep 1885, skipping to the next timestep.
# File not found for simulation 99, timestep 1886, skipping to the next timestep.
# File not found for simulation 99, timestep 1887, skipping to the next timestep.
# File not found for simulation 99, timestep 1888, skipping to the next timestep.
# File not found for simulation 99, timestep 1889, skipping to the next timestep.
# File not found for simulation 99, timestep 1890, skipping to the next timestep.
# File not found for simulation 99, timestep 1891, skipping to the next timestep.
# File not found for simulation 99, timestep 1892, skipping to the next timestep.
# File not found for simulation 99, timestep 1893, skipping to the next timestep.
# File not found for simulation 99, timestep 1894, skipping to the next timestep.
# File not found for simulation 99, timestep 1895, skipping to the next timestep.
# File not found for simulation 99, timestep 1896, skipping to the next timestep.
# File not found for simulation 99, timestep 1897, skipping to the next timestep.
# File not found for simulation 99, timestep 1898, skipping to the next timestep.
# File not found for simulation 99, timestep 1899, skipping to the next timestep.
# File not found for simulation 99, timestep 1900, skipping to the next timestep.
# File not found for simulation 99, timestep 1901, skipping to the next timestep.
# File not found for simulation 99, timestep 1902, skipping to the next timestep.
# File not found for simulation 99, timestep 1903, skipping to the next timestep.
# File not found for simulation 99, timestep 1904, skipping to the next timestep.
# File not found for simulation 99, timestep 1905, skipping to the next timestep.
# File not found for simulation 99, timestep 1906, skipping to the next timestep.
# File not found for simulation 99, timestep 1907, skipping to the next timestep.
# File not found for simulation 99, timestep 1908, skipping to the next timestep.
# File not found for simulation 99, timestep 1909, skipping to the next timestep.
# File not found for simulation 99, timestep 1910, skipping to the next timestep.
# File not found for simulation 99, timestep 1911, skipping to the next timestep.
# File not found for simulation 99, timestep 1912, skipping to the next timestep.
# File not found for simulation 99, timestep 1913, skipping to the next timestep.
# File not found for simulation 99, timestep 1914, skipping to the next timestep.
# File not found for simulation 99, timestep 1915, skipping to the next timestep.
# File not found for simulation 99, timestep 1916, skipping to the next timestep.
# File not found for simulation 99, timestep 1917, skipping to the next timestep.
# File not found for simulation 99, timestep 1918, skipping to the next timestep.
# File not found for simulation 99, timestep 1919, skipping to the next timestep.
# File not found for simulation 99, timestep 1920, skipping to the next timestep.
# File not found for simulation 99, timestep 1921, skipping to the next timestep.
# File not found for simulation 99, timestep 1922, skipping to the next timestep.
# File not found for simulation 99, timestep 1923, skipping to the next timestep.
# File not found for simulation 99, timestep 1924, skipping to the next timestep.
# File not found for simulation 99, timestep 1925, skipping to the next timestep.
# File not found for simulation 99, timestep 1926, skipping to the next timestep.
# File not found for simulation 99, timestep 1927, skipping to the next timestep.
# File not found for simulation 99, timestep 1928, skipping to the next timestep.
# File not found for simulation 99, timestep 1929, skipping to the next timestep.
# File not found for simulation 99, timestep 1930, skipping to the next timestep.
# File not found for simulation 99, timestep 1931, skipping to the next timestep.
# File not found for simulation 99, timestep 1932, skipping to the next timestep.
# File not found for simulation 99, timestep 1933, skipping to the next timestep.
# File not found for simulation 99, timestep 1934, skipping to the next timestep.
# File not found for simulation 99, timestep 1935, skipping to the next timestep.
# File not found for simulation 99, timestep 1936, skipping to the next timestep.
# File not found for simulation 99, timestep 1937, skipping to the next timestep.
# File not found for simulation 99, timestep 1938, skipping to the next timestep.
# File not found for simulation 99, timestep 1939, skipping to the next timestep.
# File not found for simulation 99, timestep 1940, skipping to the next timestep.
# File not found for simulation 99, timestep 1941, skipping to the next timestep.
# File not found for simulation 99, timestep 1942, skipping to the next timestep.
# File not found for simulation 99, timestep 1943, skipping to the next timestep.
# File not found for simulation 99, timestep 1944, skipping to the next timestep.
# File not found for simulation 99, timestep 1945, skipping to the next timestep.
# File not found for simulation 99, timestep 1946, skipping to the next timestep.
# File not found for simulation 99, timestep 1947, skipping to the next timestep.
# File not found for simulation 99, timestep 1948, skipping to the next timestep.
# File not found for simulation 99, timestep 1949, skipping to the next timestep.
# File not found for simulation 99, timestep 1950, skipping to the next timestep.
# File not found for simulation 99, timestep 1951, skipping to the next timestep.
# File not found for simulation 99, timestep 1952, skipping to the next timestep.
# File not found for simulation 99, timestep 1953, skipping to the next timestep.
# File not found for simulation 99, timestep 1954, skipping to the next timestep.
# File not found for simulation 99, timestep 1955, skipping to the next timestep.
# File not found for simulation 99, timestep 1956, skipping to the next timestep.
# File not found for simulation 99, timestep 1957, skipping to the next timestep.
# File not found for simulation 99, timestep 1958, skipping to the next timestep.
# File not found for simulation 99, timestep 1959, skipping to the next timestep.
# File not found for simulation 99, timestep 1960, skipping to the next timestep.
# File not found for simulation 99, timestep 1961, skipping to the next timestep.
# File not found for simulation 99, timestep 1962, skipping to the next timestep.
# File not found for simulation 99, timestep 1963, skipping to the next timestep.
# File not found for simulation 99, timestep 1964, skipping to the next timestep.
# File not found for simulation 99, timestep 1965, skipping to the next timestep.
# File not found for simulation 99, timestep 1966, skipping to the next timestep.
# File not found for simulation 99, timestep 1967, skipping to the next timestep.
# File not found for simulation 99, timestep 1968, skipping to the next timestep.
# File not found for simulation 99, timestep 1969, skipping to the next timestep.
# File not found for simulation 99, timestep 1970, skipping to the next timestep.
# File not found for simulation 99, timestep 1971, skipping to the next timestep.
# File not found for simulation 99, timestep 1972, skipping to the next timestep.
# File not found for simulation 99, timestep 1973, skipping to the next timestep.
# File not found for simulation 99, timestep 1974, skipping to the next timestep.
# File not found for simulation 99, timestep 1975, skipping to the next timestep.
# File not found for simulation 99, timestep 1976, skipping to the next timestep.
# File not found for simulation 99, timestep 1977, skipping to the next timestep.
# File not found for simulation 99, timestep 1978, skipping to the next timestep.
# File not found for simulation 99, timestep 1979, skipping to the next timestep.
# File not found for simulation 99, timestep 1980, skipping to the next timestep.
# File not found for simulation 99, timestep 1981, skipping to the next timestep.
# File not found for simulation 99, timestep 1982, skipping to the next timestep.
# File not found for simulation 99, timestep 1983, skipping to the next timestep.
# File not found for simulation 99, timestep 1984, skipping to the next timestep.
# File not found for simulation 99, timestep 1985, skipping to the next timestep.
# File not found for simulation 99, timestep 1986, skipping to the next timestep.
# File not found for simulation 99, timestep 1987, skipping to the next timestep.
# File not found for simulation 99, timestep 1988, skipping to the next timestep.
# File not found for simulation 99, timestep 1989, skipping to the next timestep.
# File not found for simulation 99, timestep 1990, skipping to the next timestep.
# File not found for simulation 99, timestep 1991, skipping to the next timestep.
# File not found for simulation 99, timestep 1992, skipping to the next timestep.
# File not found for simulation 99, timestep 1993, skipping to the next timestep.
# File not found for simulation 99, timestep 1994, skipping to the next timestep.
# File not found for simulation 99, timestep 1995, skipping to the next timestep.
# File not found for simulation 99, timestep 1996, skipping to the next timestep.
# Loaded simulation 100/124
# Progress: 80.65%
# Loaded simulation 101/124
# Progress: 81.45%
# Loaded simulation 102/124
# Progress: 82.26%
# Loaded simulation 103/124
# Progress: 83.06%
# Loaded simulation 108/124
# Progress: 87.10%
# Loaded simulation 107/124
# Progress: 86.29%
# Loaded simulation 105/124
# Progress: 84.68%
# Loaded simulation 106/124
# Progress: 85.48%
# Loaded simulation 109/124
# Progress: 87.90%
# Loaded simulation 110/124
# Progress: 88.71%
# Loaded simulation 114/124
# Progress: 91.94%
# Loaded simulation 115/124
# Progress: 92.74%
# Loaded simulation 117/124
# Progress: 94.35%
# Loaded simulation 121/124
# Progress: 97.58%
# Loaded simulation 120/124
# Progress: 96.77%
# Loaded simulation 122/124
# Progress: 98.39%
# Loaded simulation 119/124
# Progress: 95.97%
# Loaded simulation 123/124
# Progress: 99.19%
# Loaded simulation 124/124
# Progress: 100.00%

# %%
def save_data_as_pickle(data, filename):
    with open(filename, 'wb') as file:
        pickle.dump(data, file)
save_data_as_pickle(dataloader.data, 'data_3.pkl')

# %%
import pickle
# Open the pickle file
def load_from_pickle(filename):
    with open(filename, 'rb') as file:
        data = pickle.load(file)
    return data

data = load_from_pickle('data.pkl')

# %%
from burgers_1d_batch import Burgers_1d

burgers = Burgers_1d(resolution = 128)
# Out:
# 2024-07-19 18:11:30.504278: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-19 18:11:30.552388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-19 18:11:30.571459: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-19 18:11:30.571482: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-19 18:11:30.584047: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-19 18:11:37.219692: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-19 18:11:49.969188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /device:GPU:0 with 18211 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 3g.20gb, pci bus id: 0000:31:00.0, compute capability: 8.0
# 2024-07-19 18:11:49.983333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18211 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 3g.20gb, pci bus id: 0000:31:00.0, compute capability: 8.0

# %%
from phi.tf.flow import *

test = [item[1] for item in data[0:10]]
forcing = np.stack([item[4] for item in data[0:10]], axis=0)

print(forcing.shape)

test = test[0]

def to_phiflow_format(data):
    return CenteredGrid(math.tensor(data, spatial('x')), extrapolation.PERIODIC, x=int(128), bounds=Box['x', slice(0, 2 * np.pi)])

# Assuming test[2][1] is a list of numpy arrays or a similar iterable of data that can be converted
centered_grids = [to_phiflow_format(a) for a in test]

print(type(centered_grids))

burgers.generate_forcing_with_params(T = 0, params = forcing)

# Assuming centered_grids is a list of CenteredGrid objects
# Assuming centered_grids is a list of CenteredGrid objects
centered_grid_batch = stack(centered_grids, batch('batch'))

import time 

start = time.time()
burgers.equation_batch(centered_grid_batch, [1 for i in range(6)])
end = time.time()

print(end - start)
# Out:
# (10, 20, 4)
# <class 'list'>
# 2024-07-19 18:21:08.898670: W tensorflow/core/framework/op_kernel.cc:1827] INVALID_ARGUMENT: required broadcastable shapes
# 2024-07-19 18:21:08.898706: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: INVALID_ARGUMENT: required broadcastable shapes
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[11], line 18
#      14 centered_grids = [to_phiflow_format(a) for a in test]
#      16 print(type(centered_grids))
# ---> 18 burgers.generate_forcing_with_params(T = 0, params = forcing)
#      20 # Assuming centered_grids is a list of CenteredGrid objects
#      21 # Assuming centered_grids is a list of CenteredGrid objects
#      22 centered_grid_batch = stack(centered_grids, batch('batch'))
#
# File ~/LearnedCorrections/LearnedCorrections/1-d/1d-burgers/burgers_1d_batch.py:220, in Burgers_1d.generate_forcing_with_params(self, T, params)
#     217     φ_float = tf.cast(φ, tf.float32)
#     218     xgrid_float = tf.cast(self.xgrid, tf.float32)
# --> 220     forcing += A * tf.sin(ω_float * T_float + 2 * np.pi * l_float * xgrid_float / (2 * np.pi) + φ_float)
#     221 return forcing
#
# File ~/.conda/envs/tf2.16.1_cuda12.1/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~/.conda/envs/tf2.16.1_cuda12.1/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:5983, in raise_from_not_ok_status(e, name)
#    5981 def raise_from_not_ok_status(e, name) -> NoReturn:
#    5982   e.message += (" name: " + str(name if name is not None else ""))
# -> 5983   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:GPU:0}} required broadcastable shapes [Op:Mul] name:

# %%
print(centered_grid_batch)
# Out:
# CenteredGrid[(batchᵇ=6, xˢ=128), size=(x=6.283), extrapolation=periodic]

# %%
# Out:
# CenteredGrid[(batchᵇ=6, xˢ=128), size=(x=6.283), extrapolation=periodic]
